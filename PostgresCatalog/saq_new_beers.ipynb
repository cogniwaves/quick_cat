# %%
import pandas as pd
import numpy as np
import os
import sys
import psycopg2
DB_URL = "postgresql://postgres.oqvdwtiwrzyjpnouwxch:f87JpR9Uvud6NR3HwbP@aws-0-ca-central-1.pooler.supabase.com:5432/postgres"

# %% [markdown]
# # STEP 1 Extract data from files

# %%
import os
import json
import pandas as pd
import codecs

DATADIR = "../data/saq/products/"



def fix_unicode_escape(s):
    return codecs.decode(s, 'unicode_escape') if isinstance(s, str) else s


def extract_saq_fields_from_record(item):
    pdets = item.get("product_details", {})
    return {
        "url": item.get("url"),
        "product_name": item.get("product_name"),
        "price": item.get("price"),
        "breadcrumb": item.get("breadcrumb"),
        "product_details_pays": pdets.get("Pays"),
        "product_details_region": pdets.get("Région"),
        "product_details_appellation": pdets.get("Appellation d'origine"),
        "product_details_designation": pdets.get("Désignation réglementée"),
        "product_details_cepage": pdets.get("Cépage") or pdets.get("Cépages"),
        "product_details_degre_alcool": pdets.get("Degré d'alcool"),
        "product_details_couleur": pdets.get("Couleur"),
        "product_details_format": pdets.get("Format"),
        "product_details_producteur": pdets.get("Producteur"),
        "product_details_agent": pdets.get("Agent promotionnel"),
        "product_details_code_saq": pdets.get("Code SAQ"),
        "product_details_code_cup": pdets.get("Code CUP"),
        "product_details_tasting_notes": item.get("tasting_notes"),
        "product_details_pairings": item.get("pairings"),
        "product_details": pdets
    }

def load_data2(batch_start=1, batch_end=10):
    data = []
    for i in range(batch_start, batch_end):
        file_path = os.path.join(DATADIR, f'batch_{i}.json')
        print(f"Loading {file_path}")
        if os.path.exists(file_path):
            with open(file_path, 'r', encoding="utf-8") as f:
                records = json.load(f)
                cleaned = [extract_saq_fields_from_record(rec) for rec in records]
                data.append(pd.DataFrame(cleaned))
        else:
            print(f"File {file_path} does not exist.")
    return pd.concat(data, ignore_index=True)

# %%
df = load_data2(batch_start = 1, batch_end=1908)
df = df[df['product_name'].notna() & (df['product_name'].str.strip() != '')]
df['breadcrumb'] = df['breadcrumb'].apply(fix_unicode_escape)

df.head()
# Out:
# Loading ../data/saq/products/batch_1.json
# Loading ../data/saq/products/batch_2.json
# Loading ../data/saq/products/batch_3.json
# Loading ../data/saq/products/batch_4.json
# Loading ../data/saq/products/batch_5.json
# Loading ../data/saq/products/batch_6.json
# Loading ../data/saq/products/batch_7.json
# Loading ../data/saq/products/batch_8.json
# Loading ../data/saq/products/batch_9.json
# Loading ../data/saq/products/batch_10.json
# Loading ../data/saq/products/batch_11.json
# Loading ../data/saq/products/batch_12.json
# Loading ../data/saq/products/batch_13.json
# Loading ../data/saq/products/batch_14.json
# Loading ../data/saq/products/batch_15.json
# Loading ../data/saq/products/batch_16.json
# Loading ../data/saq/products/batch_17.json
# Loading ../data/saq/products/batch_18.json
# Loading ../data/saq/products/batch_19.json
# Loading ../data/saq/products/batch_20.json
# Loading ../data/saq/products/batch_21.json
# Loading ../data/saq/products/batch_22.json
# Loading ../data/saq/products/batch_23.json
# Loading ../data/saq/products/batch_24.json
# Loading ../data/saq/products/batch_25.json
# Loading ../data/saq/products/batch_26.json
# Loading ../data/saq/products/batch_27.json
# Loading ../data/saq/products/batch_28.json
# Loading ../data/saq/products/batch_29.json
# Loading ../data/saq/products/batch_30.json
# Loading ../data/saq/products/batch_31.json
# Loading ../data/saq/products/batch_32.json
# Loading ../data/saq/products/batch_33.json
# Loading ../data/saq/products/batch_34.json
# Loading ../data/saq/products/batch_35.json
# Loading ../data/saq/products/batch_36.json
# Loading ../data/saq/products/batch_37.json
# Loading ../data/saq/products/batch_38.json
# Loading ../data/saq/products/batch_39.json
# Loading ../data/saq/products/batch_40.json
# Loading ../data/saq/products/batch_41.json
# Loading ../data/saq/products/batch_42.json
# Loading ../data/saq/products/batch_43.json
# Loading ../data/saq/products/batch_44.json
# Loading ../data/saq/products/batch_45.json
# Loading ../data/saq/products/batch_46.json
# Loading ../data/saq/products/batch_47.json
# Loading ../data/saq/products/batch_48.json
# Loading ../data/saq/products/batch_49.json
# Loading ../data/saq/products/batch_50.json
# Loading ../data/saq/products/batch_51.json
# Loading ../data/saq/products/batch_52.json
# Loading ../data/saq/products/batch_53.json
# Loading ../data/saq/products/batch_54.json
# Loading ../data/saq/products/batch_55.json
# Loading ../data/saq/products/batch_56.json
# Loading ../data/saq/products/batch_57.json
# Loading ../data/saq/products/batch_58.json
# Loading ../data/saq/products/batch_59.json
# Loading ../data/saq/products/batch_60.json
# Loading ../data/saq/products/batch_61.json
# Loading ../data/saq/products/batch_62.json
# Loading ../data/saq/products/batch_63.json
# Loading ../data/saq/products/batch_64.json
# Loading ../data/saq/products/batch_65.json
# Loading ../data/saq/products/batch_66.json
# Loading ../data/saq/products/batch_67.json
# Loading ../data/saq/products/batch_68.json
# Loading ../data/saq/products/batch_69.json
# Loading ../data/saq/products/batch_70.json
# Loading ../data/saq/products/batch_71.json
# Loading ../data/saq/products/batch_72.json
# Loading ../data/saq/products/batch_73.json
# Loading ../data/saq/products/batch_74.json
# Loading ../data/saq/products/batch_75.json
# Loading ../data/saq/products/batch_76.json
# Loading ../data/saq/products/batch_77.json
# Loading ../data/saq/products/batch_78.json
# Loading ../data/saq/products/batch_79.json
# Loading ../data/saq/products/batch_80.json
# Loading ../data/saq/products/batch_81.json
# Loading ../data/saq/products/batch_82.json
# Loading ../data/saq/products/batch_83.json
# Loading ../data/saq/products/batch_84.json
# Loading ../data/saq/products/batch_85.json
# Loading ../data/saq/products/batch_86.json
# Loading ../data/saq/products/batch_87.json
# Loading ../data/saq/products/batch_88.json
# Loading ../data/saq/products/batch_89.json
# Loading ../data/saq/products/batch_90.json
# Loading ../data/saq/products/batch_91.json
# Loading ../data/saq/products/batch_92.json
# Loading ../data/saq/products/batch_93.json
# Loading ../data/saq/products/batch_94.json
# Loading ../data/saq/products/batch_95.json
# Loading ../data/saq/products/batch_96.json
# Loading ../data/saq/products/batch_97.json
# Loading ../data/saq/products/batch_98.json
# Loading ../data/saq/products/batch_99.json
# Loading ../data/saq/products/batch_100.json
# Loading ../data/saq/products/batch_101.json
# Loading ../data/saq/products/batch_102.json
# Loading ../data/saq/products/batch_103.json
# Loading ../data/saq/products/batch_104.json
# Loading ../data/saq/products/batch_105.json
# Loading ../data/saq/products/batch_106.json
# Loading ../data/saq/products/batch_107.json
# Loading ../data/saq/products/batch_108.json
# Loading ../data/saq/products/batch_109.json
# Loading ../data/saq/products/batch_110.json
# Loading ../data/saq/products/batch_111.json
# Loading ../data/saq/products/batch_112.json
# Loading ../data/saq/products/batch_113.json
# Loading ../data/saq/products/batch_114.json
# Loading ../data/saq/products/batch_115.json
# Loading ../data/saq/products/batch_116.json
# Loading ../data/saq/products/batch_117.json
# Loading ../data/saq/products/batch_118.json
# Loading ../data/saq/products/batch_119.json
# Loading ../data/saq/products/batch_120.json
# Loading ../data/saq/products/batch_121.json
# Loading ../data/saq/products/batch_122.json
# Loading ../data/saq/products/batch_123.json
# Loading ../data/saq/products/batch_124.json
# Loading ../data/saq/products/batch_125.json
# Loading ../data/saq/products/batch_126.json
# Loading ../data/saq/products/batch_127.json
# Loading ../data/saq/products/batch_128.json
# Loading ../data/saq/products/batch_129.json
# Loading ../data/saq/products/batch_130.json
# Loading ../data/saq/products/batch_131.json
# Loading ../data/saq/products/batch_132.json
# Loading ../data/saq/products/batch_133.json
# Loading ../data/saq/products/batch_134.json
# Loading ../data/saq/products/batch_135.json
# Loading ../data/saq/products/batch_136.json
# Loading ../data/saq/products/batch_137.json
# Loading ../data/saq/products/batch_138.json
# Loading ../data/saq/products/batch_139.json
# Loading ../data/saq/products/batch_140.json
# Loading ../data/saq/products/batch_141.json
# Loading ../data/saq/products/batch_142.json
# Loading ../data/saq/products/batch_143.json
# Loading ../data/saq/products/batch_144.json
# Loading ../data/saq/products/batch_145.json
# Loading ../data/saq/products/batch_146.json
# Loading ../data/saq/products/batch_147.json
# Loading ../data/saq/products/batch_148.json
# Loading ../data/saq/products/batch_149.json
# Loading ../data/saq/products/batch_150.json
# Loading ../data/saq/products/batch_151.json
# Loading ../data/saq/products/batch_152.json
# Loading ../data/saq/products/batch_153.json
# Loading ../data/saq/products/batch_154.json
# Loading ../data/saq/products/batch_155.json
# Loading ../data/saq/products/batch_156.json
# Loading ../data/saq/products/batch_157.json
# Loading ../data/saq/products/batch_158.json
# Loading ../data/saq/products/batch_159.json
# Loading ../data/saq/products/batch_160.json
# Loading ../data/saq/products/batch_161.json
# Loading ../data/saq/products/batch_162.json
# Loading ../data/saq/products/batch_163.json
# Loading ../data/saq/products/batch_164.json
# Loading ../data/saq/products/batch_165.json
# Loading ../data/saq/products/batch_166.json
# Loading ../data/saq/products/batch_167.json
# Loading ../data/saq/products/batch_168.json
# Loading ../data/saq/products/batch_169.json
# Loading ../data/saq/products/batch_170.json
# Loading ../data/saq/products/batch_171.json
# Loading ../data/saq/products/batch_172.json
# Loading ../data/saq/products/batch_173.json
# Loading ../data/saq/products/batch_174.json
# Loading ../data/saq/products/batch_175.json
# Loading ../data/saq/products/batch_176.json
# Loading ../data/saq/products/batch_177.json
# Loading ../data/saq/products/batch_178.json
# Loading ../data/saq/products/batch_179.json
# Loading ../data/saq/products/batch_180.json
# Loading ../data/saq/products/batch_181.json
# Loading ../data/saq/products/batch_182.json
# Loading ../data/saq/products/batch_183.json
# Loading ../data/saq/products/batch_184.json
# Loading ../data/saq/products/batch_185.json
# Loading ../data/saq/products/batch_186.json
# Loading ../data/saq/products/batch_187.json
# Loading ../data/saq/products/batch_188.json
# Loading ../data/saq/products/batch_189.json
# Loading ../data/saq/products/batch_190.json
# Loading ../data/saq/products/batch_191.json
# Loading ../data/saq/products/batch_192.json
# Loading ../data/saq/products/batch_193.json
# Loading ../data/saq/products/batch_194.json
# Loading ../data/saq/products/batch_195.json
# Loading ../data/saq/products/batch_196.json
# Loading ../data/saq/products/batch_197.json
# Loading ../data/saq/products/batch_198.json
# Loading ../data/saq/products/batch_199.json
# Loading ../data/saq/products/batch_200.json
# Loading ../data/saq/products/batch_201.json
# Loading ../data/saq/products/batch_202.json
# Loading ../data/saq/products/batch_203.json
# Loading ../data/saq/products/batch_204.json
# Loading ../data/saq/products/batch_205.json
# Loading ../data/saq/products/batch_206.json
# Loading ../data/saq/products/batch_207.json
# Loading ../data/saq/products/batch_208.json
# Loading ../data/saq/products/batch_209.json
# Loading ../data/saq/products/batch_210.json
# Loading ../data/saq/products/batch_211.json
# Loading ../data/saq/products/batch_212.json
# Loading ../data/saq/products/batch_213.json
# Loading ../data/saq/products/batch_214.json
# Loading ../data/saq/products/batch_215.json
# Loading ../data/saq/products/batch_216.json
# Loading ../data/saq/products/batch_217.json
# Loading ../data/saq/products/batch_218.json
# Loading ../data/saq/products/batch_219.json
# Loading ../data/saq/products/batch_220.json
# Loading ../data/saq/products/batch_221.json
# Loading ../data/saq/products/batch_222.json
# Loading ../data/saq/products/batch_223.json
# Loading ../data/saq/products/batch_224.json
# Loading ../data/saq/products/batch_225.json
# Loading ../data/saq/products/batch_226.json
# Loading ../data/saq/products/batch_227.json
# Loading ../data/saq/products/batch_228.json
# Loading ../data/saq/products/batch_229.json
# Loading ../data/saq/products/batch_230.json
# Loading ../data/saq/products/batch_231.json
# Loading ../data/saq/products/batch_232.json
# Loading ../data/saq/products/batch_233.json
# Loading ../data/saq/products/batch_234.json
# Loading ../data/saq/products/batch_235.json
# Loading ../data/saq/products/batch_236.json
# Loading ../data/saq/products/batch_237.json
# Loading ../data/saq/products/batch_238.json
# Loading ../data/saq/products/batch_239.json
# Loading ../data/saq/products/batch_240.json
# Loading ../data/saq/products/batch_241.json
# Loading ../data/saq/products/batch_242.json
# Loading ../data/saq/products/batch_243.json
# Loading ../data/saq/products/batch_244.json
# Loading ../data/saq/products/batch_245.json
# Loading ../data/saq/products/batch_246.json
# Loading ../data/saq/products/batch_247.json
# Loading ../data/saq/products/batch_248.json
# Loading ../data/saq/products/batch_249.json
# Loading ../data/saq/products/batch_250.json
# Loading ../data/saq/products/batch_251.json
# Loading ../data/saq/products/batch_252.json
# Loading ../data/saq/products/batch_253.json
# Loading ../data/saq/products/batch_254.json
# Loading ../data/saq/products/batch_255.json
# Loading ../data/saq/products/batch_256.json
# Loading ../data/saq/products/batch_257.json
# Loading ../data/saq/products/batch_258.json
# Loading ../data/saq/products/batch_259.json
# Loading ../data/saq/products/batch_260.json
# Loading ../data/saq/products/batch_261.json
# Loading ../data/saq/products/batch_262.json
# Loading ../data/saq/products/batch_263.json
# Loading ../data/saq/products/batch_264.json
# Loading ../data/saq/products/batch_265.json
# Loading ../data/saq/products/batch_266.json
# Loading ../data/saq/products/batch_267.json
# Loading ../data/saq/products/batch_268.json
# Loading ../data/saq/products/batch_269.json
# Loading ../data/saq/products/batch_270.json
# Loading ../data/saq/products/batch_271.json
# Loading ../data/saq/products/batch_272.json
# Loading ../data/saq/products/batch_273.json
# Loading ../data/saq/products/batch_274.json
# Loading ../data/saq/products/batch_275.json
# Loading ../data/saq/products/batch_276.json
# Loading ../data/saq/products/batch_277.json
# Loading ../data/saq/products/batch_278.json
# Loading ../data/saq/products/batch_279.json
# Loading ../data/saq/products/batch_280.json
# Loading ../data/saq/products/batch_281.json
# Loading ../data/saq/products/batch_282.json
# Loading ../data/saq/products/batch_283.json
# Loading ../data/saq/products/batch_284.json
# Loading ../data/saq/products/batch_285.json
# Loading ../data/saq/products/batch_286.json
# Loading ../data/saq/products/batch_287.json
# Loading ../data/saq/products/batch_288.json
# Loading ../data/saq/products/batch_289.json
# Loading ../data/saq/products/batch_290.json
# Loading ../data/saq/products/batch_291.json
# Loading ../data/saq/products/batch_292.json
# Loading ../data/saq/products/batch_293.json
# Loading ../data/saq/products/batch_294.json
# Loading ../data/saq/products/batch_295.json
# Loading ../data/saq/products/batch_296.json
# Loading ../data/saq/products/batch_297.json
# Loading ../data/saq/products/batch_298.json
# Loading ../data/saq/products/batch_299.json
# Loading ../data/saq/products/batch_300.json
# Loading ../data/saq/products/batch_301.json
# Loading ../data/saq/products/batch_302.json
# Loading ../data/saq/products/batch_303.json
# Loading ../data/saq/products/batch_304.json
# Loading ../data/saq/products/batch_305.json
# Loading ../data/saq/products/batch_306.json
# Loading ../data/saq/products/batch_307.json
# Loading ../data/saq/products/batch_308.json
# Loading ../data/saq/products/batch_309.json
# Loading ../data/saq/products/batch_310.json
# Loading ../data/saq/products/batch_311.json
# Loading ../data/saq/products/batch_312.json
# Loading ../data/saq/products/batch_313.json
# Loading ../data/saq/products/batch_314.json
# Loading ../data/saq/products/batch_315.json
# Loading ../data/saq/products/batch_316.json
# Loading ../data/saq/products/batch_317.json
# Loading ../data/saq/products/batch_318.json
# Loading ../data/saq/products/batch_319.json
# Loading ../data/saq/products/batch_320.json
# Loading ../data/saq/products/batch_321.json
# Loading ../data/saq/products/batch_322.json
# Loading ../data/saq/products/batch_323.json
# Loading ../data/saq/products/batch_324.json
# Loading ../data/saq/products/batch_325.json
# Loading ../data/saq/products/batch_326.json
# Loading ../data/saq/products/batch_327.json
# Loading ../data/saq/products/batch_328.json
# Loading ../data/saq/products/batch_329.json
# Loading ../data/saq/products/batch_330.json
# Loading ../data/saq/products/batch_331.json
# Loading ../data/saq/products/batch_332.json
# Loading ../data/saq/products/batch_333.json
# Loading ../data/saq/products/batch_334.json
# Loading ../data/saq/products/batch_335.json
# Loading ../data/saq/products/batch_336.json
# Loading ../data/saq/products/batch_337.json
# Loading ../data/saq/products/batch_338.json
# Loading ../data/saq/products/batch_339.json
# Loading ../data/saq/products/batch_340.json
# Loading ../data/saq/products/batch_341.json
# Loading ../data/saq/products/batch_342.json
# Loading ../data/saq/products/batch_343.json
# Loading ../data/saq/products/batch_344.json
# Loading ../data/saq/products/batch_345.json
# Loading ../data/saq/products/batch_346.json
# Loading ../data/saq/products/batch_347.json
# Loading ../data/saq/products/batch_348.json
# Loading ../data/saq/products/batch_349.json
# Loading ../data/saq/products/batch_350.json
# Loading ../data/saq/products/batch_351.json
# Loading ../data/saq/products/batch_352.json
# Loading ../data/saq/products/batch_353.json
# Loading ../data/saq/products/batch_354.json
# Loading ../data/saq/products/batch_355.json
# Loading ../data/saq/products/batch_356.json
# Loading ../data/saq/products/batch_357.json
# Loading ../data/saq/products/batch_358.json
# Loading ../data/saq/products/batch_359.json
# Loading ../data/saq/products/batch_360.json
# Loading ../data/saq/products/batch_361.json
# Loading ../data/saq/products/batch_362.json
# Loading ../data/saq/products/batch_363.json
# Loading ../data/saq/products/batch_364.json
# Loading ../data/saq/products/batch_365.json
# Loading ../data/saq/products/batch_366.json
# Loading ../data/saq/products/batch_367.json
# Loading ../data/saq/products/batch_368.json
# Loading ../data/saq/products/batch_369.json
# Loading ../data/saq/products/batch_370.json
# Loading ../data/saq/products/batch_371.json
# Loading ../data/saq/products/batch_372.json
# Loading ../data/saq/products/batch_373.json
# Loading ../data/saq/products/batch_374.json
# Loading ../data/saq/products/batch_375.json
# Loading ../data/saq/products/batch_376.json
# Loading ../data/saq/products/batch_377.json
# Loading ../data/saq/products/batch_378.json
# Loading ../data/saq/products/batch_379.json
# Loading ../data/saq/products/batch_380.json
# Loading ../data/saq/products/batch_381.json
# Loading ../data/saq/products/batch_382.json
# Loading ../data/saq/products/batch_383.json
# Loading ../data/saq/products/batch_384.json
# Loading ../data/saq/products/batch_385.json
# Loading ../data/saq/products/batch_386.json
# Loading ../data/saq/products/batch_387.json
# Loading ../data/saq/products/batch_388.json
# Loading ../data/saq/products/batch_389.json
# Loading ../data/saq/products/batch_390.json
# Loading ../data/saq/products/batch_391.json
# Loading ../data/saq/products/batch_392.json
# Loading ../data/saq/products/batch_393.json
# Loading ../data/saq/products/batch_394.json
# Loading ../data/saq/products/batch_395.json
# Loading ../data/saq/products/batch_396.json
# Loading ../data/saq/products/batch_397.json
# Loading ../data/saq/products/batch_398.json
# Loading ../data/saq/products/batch_399.json
# Loading ../data/saq/products/batch_400.json
# Loading ../data/saq/products/batch_401.json
# Loading ../data/saq/products/batch_402.json
# Loading ../data/saq/products/batch_403.json
# Loading ../data/saq/products/batch_404.json
# Loading ../data/saq/products/batch_405.json
# Loading ../data/saq/products/batch_406.json
# Loading ../data/saq/products/batch_407.json
# Loading ../data/saq/products/batch_408.json
# Loading ../data/saq/products/batch_409.json
# Loading ../data/saq/products/batch_410.json
# Loading ../data/saq/products/batch_411.json
# Loading ../data/saq/products/batch_412.json
# Loading ../data/saq/products/batch_413.json
# Loading ../data/saq/products/batch_414.json
# Loading ../data/saq/products/batch_415.json
# Loading ../data/saq/products/batch_416.json
# Loading ../data/saq/products/batch_417.json
# Loading ../data/saq/products/batch_418.json
# Loading ../data/saq/products/batch_419.json
# Loading ../data/saq/products/batch_420.json
# Loading ../data/saq/products/batch_421.json
# Loading ../data/saq/products/batch_422.json
# Loading ../data/saq/products/batch_423.json
# Loading ../data/saq/products/batch_424.json
# Loading ../data/saq/products/batch_425.json
# Loading ../data/saq/products/batch_426.json
# Loading ../data/saq/products/batch_427.json
# Loading ../data/saq/products/batch_428.json
# Loading ../data/saq/products/batch_429.json
# Loading ../data/saq/products/batch_430.json
# Loading ../data/saq/products/batch_431.json
# Loading ../data/saq/products/batch_432.json
# Loading ../data/saq/products/batch_433.json
# Loading ../data/saq/products/batch_434.json
# Loading ../data/saq/products/batch_435.json
# Loading ../data/saq/products/batch_436.json
# Loading ../data/saq/products/batch_437.json
# Loading ../data/saq/products/batch_438.json
# Loading ../data/saq/products/batch_439.json
# Loading ../data/saq/products/batch_440.json
# Loading ../data/saq/products/batch_441.json
# Loading ../data/saq/products/batch_442.json
# Loading ../data/saq/products/batch_443.json
# Loading ../data/saq/products/batch_444.json
# Loading ../data/saq/products/batch_445.json
# Loading ../data/saq/products/batch_446.json
# Loading ../data/saq/products/batch_447.json
# Loading ../data/saq/products/batch_448.json
# Loading ../data/saq/products/batch_449.json
# Loading ../data/saq/products/batch_450.json
# Loading ../data/saq/products/batch_451.json
# Loading ../data/saq/products/batch_452.json
# Loading ../data/saq/products/batch_453.json
# Loading ../data/saq/products/batch_454.json
# Loading ../data/saq/products/batch_455.json
# Loading ../data/saq/products/batch_456.json
# Loading ../data/saq/products/batch_457.json
# Loading ../data/saq/products/batch_458.json
# Loading ../data/saq/products/batch_459.json
# Loading ../data/saq/products/batch_460.json
# Loading ../data/saq/products/batch_461.json
# Loading ../data/saq/products/batch_462.json
# Loading ../data/saq/products/batch_463.json
# Loading ../data/saq/products/batch_464.json
# Loading ../data/saq/products/batch_465.json
# Loading ../data/saq/products/batch_466.json
# Loading ../data/saq/products/batch_467.json
# Loading ../data/saq/products/batch_468.json
# Loading ../data/saq/products/batch_469.json
# Loading ../data/saq/products/batch_470.json
# Loading ../data/saq/products/batch_471.json
# Loading ../data/saq/products/batch_472.json
# Loading ../data/saq/products/batch_473.json
# Loading ../data/saq/products/batch_474.json
# Loading ../data/saq/products/batch_475.json
# Loading ../data/saq/products/batch_476.json
# Loading ../data/saq/products/batch_477.json
# Loading ../data/saq/products/batch_478.json
# Loading ../data/saq/products/batch_479.json
# Loading ../data/saq/products/batch_480.json
# Loading ../data/saq/products/batch_481.json
# Loading ../data/saq/products/batch_482.json
# Loading ../data/saq/products/batch_483.json
# Loading ../data/saq/products/batch_484.json
# Loading ../data/saq/products/batch_485.json
# Loading ../data/saq/products/batch_486.json
# Loading ../data/saq/products/batch_487.json
# Loading ../data/saq/products/batch_488.json
# Loading ../data/saq/products/batch_489.json
# Loading ../data/saq/products/batch_490.json
# Loading ../data/saq/products/batch_491.json
# Loading ../data/saq/products/batch_492.json
# Loading ../data/saq/products/batch_493.json
# Loading ../data/saq/products/batch_494.json
# Loading ../data/saq/products/batch_495.json
# Loading ../data/saq/products/batch_496.json
# Loading ../data/saq/products/batch_497.json
# Loading ../data/saq/products/batch_498.json
# Loading ../data/saq/products/batch_499.json
# Loading ../data/saq/products/batch_500.json
# Loading ../data/saq/products/batch_501.json
# Loading ../data/saq/products/batch_502.json
# Loading ../data/saq/products/batch_503.json
# Loading ../data/saq/products/batch_504.json
# Loading ../data/saq/products/batch_505.json
# Loading ../data/saq/products/batch_506.json
# Loading ../data/saq/products/batch_507.json
# Loading ../data/saq/products/batch_508.json
# Loading ../data/saq/products/batch_509.json
# Loading ../data/saq/products/batch_510.json
# Loading ../data/saq/products/batch_511.json
# Loading ../data/saq/products/batch_512.json
# Loading ../data/saq/products/batch_513.json
# Loading ../data/saq/products/batch_514.json
# Loading ../data/saq/products/batch_515.json
# Loading ../data/saq/products/batch_516.json
# Loading ../data/saq/products/batch_517.json
# Loading ../data/saq/products/batch_518.json
# Loading ../data/saq/products/batch_519.json
# Loading ../data/saq/products/batch_520.json
# Loading ../data/saq/products/batch_521.json
# Loading ../data/saq/products/batch_522.json
# Loading ../data/saq/products/batch_523.json
# Loading ../data/saq/products/batch_524.json
# Loading ../data/saq/products/batch_525.json
# Loading ../data/saq/products/batch_526.json
# Loading ../data/saq/products/batch_527.json
# Loading ../data/saq/products/batch_528.json
# Loading ../data/saq/products/batch_529.json
# Loading ../data/saq/products/batch_530.json
# Loading ../data/saq/products/batch_531.json
# Loading ../data/saq/products/batch_532.json
# Loading ../data/saq/products/batch_533.json
# Loading ../data/saq/products/batch_534.json
# Loading ../data/saq/products/batch_535.json
# Loading ../data/saq/products/batch_536.json
# Loading ../data/saq/products/batch_537.json
# Loading ../data/saq/products/batch_538.json
# Loading ../data/saq/products/batch_539.json
# Loading ../data/saq/products/batch_540.json
# Loading ../data/saq/products/batch_541.json
# Loading ../data/saq/products/batch_542.json
# Loading ../data/saq/products/batch_543.json
# Loading ../data/saq/products/batch_544.json
# Loading ../data/saq/products/batch_545.json
# Loading ../data/saq/products/batch_546.json
# Loading ../data/saq/products/batch_547.json
# Loading ../data/saq/products/batch_548.json
# Loading ../data/saq/products/batch_549.json
# Loading ../data/saq/products/batch_550.json
# Loading ../data/saq/products/batch_551.json
# Loading ../data/saq/products/batch_552.json
# Loading ../data/saq/products/batch_553.json
# Loading ../data/saq/products/batch_554.json
# Loading ../data/saq/products/batch_555.json
# Loading ../data/saq/products/batch_556.json
# Loading ../data/saq/products/batch_557.json
# Loading ../data/saq/products/batch_558.json
# Loading ../data/saq/products/batch_559.json
# Loading ../data/saq/products/batch_560.json
# Loading ../data/saq/products/batch_561.json
# Loading ../data/saq/products/batch_562.json
# Loading ../data/saq/products/batch_563.json
# Loading ../data/saq/products/batch_564.json
# Loading ../data/saq/products/batch_565.json
# Loading ../data/saq/products/batch_566.json
# Loading ../data/saq/products/batch_567.json
# Loading ../data/saq/products/batch_568.json
# Loading ../data/saq/products/batch_569.json
# Loading ../data/saq/products/batch_570.json
# Loading ../data/saq/products/batch_571.json
# Loading ../data/saq/products/batch_572.json
# Loading ../data/saq/products/batch_573.json
# Loading ../data/saq/products/batch_574.json
# Loading ../data/saq/products/batch_575.json
# Loading ../data/saq/products/batch_576.json
# Loading ../data/saq/products/batch_577.json
# Loading ../data/saq/products/batch_578.json
# Loading ../data/saq/products/batch_579.json
# Loading ../data/saq/products/batch_580.json
# Loading ../data/saq/products/batch_581.json
# Loading ../data/saq/products/batch_582.json
# Loading ../data/saq/products/batch_583.json
# Loading ../data/saq/products/batch_584.json
# Loading ../data/saq/products/batch_585.json
# Loading ../data/saq/products/batch_586.json
# Loading ../data/saq/products/batch_587.json
# Loading ../data/saq/products/batch_588.json
# Loading ../data/saq/products/batch_589.json
# Loading ../data/saq/products/batch_590.json
# Loading ../data/saq/products/batch_591.json
# Loading ../data/saq/products/batch_592.json
# Loading ../data/saq/products/batch_593.json
# Loading ../data/saq/products/batch_594.json
# Loading ../data/saq/products/batch_595.json
# Loading ../data/saq/products/batch_596.json
# Loading ../data/saq/products/batch_597.json
# Loading ../data/saq/products/batch_598.json
# Loading ../data/saq/products/batch_599.json
# Loading ../data/saq/products/batch_600.json
# Loading ../data/saq/products/batch_601.json
# Loading ../data/saq/products/batch_602.json
# Loading ../data/saq/products/batch_603.json
# Loading ../data/saq/products/batch_604.json
# Loading ../data/saq/products/batch_605.json
# Loading ../data/saq/products/batch_606.json
# Loading ../data/saq/products/batch_607.json
# Loading ../data/saq/products/batch_608.json
# Loading ../data/saq/products/batch_609.json
# Loading ../data/saq/products/batch_610.json
# Loading ../data/saq/products/batch_611.json
# Loading ../data/saq/products/batch_612.json
# Loading ../data/saq/products/batch_613.json
# Loading ../data/saq/products/batch_614.json
# Loading ../data/saq/products/batch_615.json
# Loading ../data/saq/products/batch_616.json
# Loading ../data/saq/products/batch_617.json
# Loading ../data/saq/products/batch_618.json
# Loading ../data/saq/products/batch_619.json
# Loading ../data/saq/products/batch_620.json
# Loading ../data/saq/products/batch_621.json
# Loading ../data/saq/products/batch_622.json
# Loading ../data/saq/products/batch_623.json
# Loading ../data/saq/products/batch_624.json
# Loading ../data/saq/products/batch_625.json
# Loading ../data/saq/products/batch_626.json
# Loading ../data/saq/products/batch_627.json
# Loading ../data/saq/products/batch_628.json
# Loading ../data/saq/products/batch_629.json
# Loading ../data/saq/products/batch_630.json
# Loading ../data/saq/products/batch_631.json
# Loading ../data/saq/products/batch_632.json
# Loading ../data/saq/products/batch_633.json
# Loading ../data/saq/products/batch_634.json
# Loading ../data/saq/products/batch_635.json
# Loading ../data/saq/products/batch_636.json
# Loading ../data/saq/products/batch_637.json
# Loading ../data/saq/products/batch_638.json
# Loading ../data/saq/products/batch_639.json
# Loading ../data/saq/products/batch_640.json
# Loading ../data/saq/products/batch_641.json
# Loading ../data/saq/products/batch_642.json
# Loading ../data/saq/products/batch_643.json
# Loading ../data/saq/products/batch_644.json
# Loading ../data/saq/products/batch_645.json
# Loading ../data/saq/products/batch_646.json
# Loading ../data/saq/products/batch_647.json
# Loading ../data/saq/products/batch_648.json
# Loading ../data/saq/products/batch_649.json
# Loading ../data/saq/products/batch_650.json
# Loading ../data/saq/products/batch_651.json
# Loading ../data/saq/products/batch_652.json
# Loading ../data/saq/products/batch_653.json
# Loading ../data/saq/products/batch_654.json
# Loading ../data/saq/products/batch_655.json
# Loading ../data/saq/products/batch_656.json
# Loading ../data/saq/products/batch_657.json
# Loading ../data/saq/products/batch_658.json
# Loading ../data/saq/products/batch_659.json
# Loading ../data/saq/products/batch_660.json
# Loading ../data/saq/products/batch_661.json
# Loading ../data/saq/products/batch_662.json
# Loading ../data/saq/products/batch_663.json
# Loading ../data/saq/products/batch_664.json
# Loading ../data/saq/products/batch_665.json
# Loading ../data/saq/products/batch_666.json
# Loading ../data/saq/products/batch_667.json
# Loading ../data/saq/products/batch_668.json
# Loading ../data/saq/products/batch_669.json
# Loading ../data/saq/products/batch_670.json
# Loading ../data/saq/products/batch_671.json
# Loading ../data/saq/products/batch_672.json
# Loading ../data/saq/products/batch_673.json
# Loading ../data/saq/products/batch_674.json
# Loading ../data/saq/products/batch_675.json
# Loading ../data/saq/products/batch_676.json
# Loading ../data/saq/products/batch_677.json
# Loading ../data/saq/products/batch_678.json
# Loading ../data/saq/products/batch_679.json
# Loading ../data/saq/products/batch_680.json
# Loading ../data/saq/products/batch_681.json
# Loading ../data/saq/products/batch_682.json
# Loading ../data/saq/products/batch_683.json
# Loading ../data/saq/products/batch_684.json
# Loading ../data/saq/products/batch_685.json
# Loading ../data/saq/products/batch_686.json
# Loading ../data/saq/products/batch_687.json
# Loading ../data/saq/products/batch_688.json
# Loading ../data/saq/products/batch_689.json
# Loading ../data/saq/products/batch_690.json
# Loading ../data/saq/products/batch_691.json
# Loading ../data/saq/products/batch_692.json
# Loading ../data/saq/products/batch_693.json
# Loading ../data/saq/products/batch_694.json
# Loading ../data/saq/products/batch_695.json
# Loading ../data/saq/products/batch_696.json
# Loading ../data/saq/products/batch_697.json
# Loading ../data/saq/products/batch_698.json
# Loading ../data/saq/products/batch_699.json
# Loading ../data/saq/products/batch_700.json
# Loading ../data/saq/products/batch_701.json
# Loading ../data/saq/products/batch_702.json
# Loading ../data/saq/products/batch_703.json
# Loading ../data/saq/products/batch_704.json
# Loading ../data/saq/products/batch_705.json
# Loading ../data/saq/products/batch_706.json
# Loading ../data/saq/products/batch_707.json
# Loading ../data/saq/products/batch_708.json
# Loading ../data/saq/products/batch_709.json
# Loading ../data/saq/products/batch_710.json
# Loading ../data/saq/products/batch_711.json
# Loading ../data/saq/products/batch_712.json
# Loading ../data/saq/products/batch_713.json
# Loading ../data/saq/products/batch_714.json
# Loading ../data/saq/products/batch_715.json
# Loading ../data/saq/products/batch_716.json
# Loading ../data/saq/products/batch_717.json
# Loading ../data/saq/products/batch_718.json
# Loading ../data/saq/products/batch_719.json
# Loading ../data/saq/products/batch_720.json
# Loading ../data/saq/products/batch_721.json
# Loading ../data/saq/products/batch_722.json
# Loading ../data/saq/products/batch_723.json
# Loading ../data/saq/products/batch_724.json
# Loading ../data/saq/products/batch_725.json
# Loading ../data/saq/products/batch_726.json
# Loading ../data/saq/products/batch_727.json
# Loading ../data/saq/products/batch_728.json
# Loading ../data/saq/products/batch_729.json
# Loading ../data/saq/products/batch_730.json
# Loading ../data/saq/products/batch_731.json
# Loading ../data/saq/products/batch_732.json
# Loading ../data/saq/products/batch_733.json
# Loading ../data/saq/products/batch_734.json
# Loading ../data/saq/products/batch_735.json
# Loading ../data/saq/products/batch_736.json
# Loading ../data/saq/products/batch_737.json
# Loading ../data/saq/products/batch_738.json
# Loading ../data/saq/products/batch_739.json
# Loading ../data/saq/products/batch_740.json
# Loading ../data/saq/products/batch_741.json
# Loading ../data/saq/products/batch_742.json
# Loading ../data/saq/products/batch_743.json
# Loading ../data/saq/products/batch_744.json
# Loading ../data/saq/products/batch_745.json
# Loading ../data/saq/products/batch_746.json
# Loading ../data/saq/products/batch_747.json
# Loading ../data/saq/products/batch_748.json
# Loading ../data/saq/products/batch_749.json
# Loading ../data/saq/products/batch_750.json
# Loading ../data/saq/products/batch_751.json
# Loading ../data/saq/products/batch_752.json
# Loading ../data/saq/products/batch_753.json
# Loading ../data/saq/products/batch_754.json
# Loading ../data/saq/products/batch_755.json
# Loading ../data/saq/products/batch_756.json
# Loading ../data/saq/products/batch_757.json
# Loading ../data/saq/products/batch_758.json
# Loading ../data/saq/products/batch_759.json
# Loading ../data/saq/products/batch_760.json
# Loading ../data/saq/products/batch_761.json
# Loading ../data/saq/products/batch_762.json
# Loading ../data/saq/products/batch_763.json
# Loading ../data/saq/products/batch_764.json
# Loading ../data/saq/products/batch_765.json
# Loading ../data/saq/products/batch_766.json
# Loading ../data/saq/products/batch_767.json
# Loading ../data/saq/products/batch_768.json
# Loading ../data/saq/products/batch_769.json
# Loading ../data/saq/products/batch_770.json
# Loading ../data/saq/products/batch_771.json
# Loading ../data/saq/products/batch_772.json
# Loading ../data/saq/products/batch_773.json
# Loading ../data/saq/products/batch_774.json
# Loading ../data/saq/products/batch_775.json
# Loading ../data/saq/products/batch_776.json
# Loading ../data/saq/products/batch_777.json
# Loading ../data/saq/products/batch_778.json
# Loading ../data/saq/products/batch_779.json
# Loading ../data/saq/products/batch_780.json
# Loading ../data/saq/products/batch_781.json
# Loading ../data/saq/products/batch_782.json
# Loading ../data/saq/products/batch_783.json
# Loading ../data/saq/products/batch_784.json
# Loading ../data/saq/products/batch_785.json
# Loading ../data/saq/products/batch_786.json
# Loading ../data/saq/products/batch_787.json
# Loading ../data/saq/products/batch_788.json
# Loading ../data/saq/products/batch_789.json
# Loading ../data/saq/products/batch_790.json
# Loading ../data/saq/products/batch_791.json
# Loading ../data/saq/products/batch_792.json
# Loading ../data/saq/products/batch_793.json
# Loading ../data/saq/products/batch_794.json
# Loading ../data/saq/products/batch_795.json
# Loading ../data/saq/products/batch_796.json
# Loading ../data/saq/products/batch_797.json
# Loading ../data/saq/products/batch_798.json
# Loading ../data/saq/products/batch_799.json
# Loading ../data/saq/products/batch_800.json
# Loading ../data/saq/products/batch_801.json
# Loading ../data/saq/products/batch_802.json
# Loading ../data/saq/products/batch_803.json
# Loading ../data/saq/products/batch_804.json
# Loading ../data/saq/products/batch_805.json
# Loading ../data/saq/products/batch_806.json
# Loading ../data/saq/products/batch_807.json
# Loading ../data/saq/products/batch_808.json
# Loading ../data/saq/products/batch_809.json
# Loading ../data/saq/products/batch_810.json
# Loading ../data/saq/products/batch_811.json
# Loading ../data/saq/products/batch_812.json
# Loading ../data/saq/products/batch_813.json
# Loading ../data/saq/products/batch_814.json
# Loading ../data/saq/products/batch_815.json
# Loading ../data/saq/products/batch_816.json
# Loading ../data/saq/products/batch_817.json
# Loading ../data/saq/products/batch_818.json
# Loading ../data/saq/products/batch_819.json
# Loading ../data/saq/products/batch_820.json
# Loading ../data/saq/products/batch_821.json
# Loading ../data/saq/products/batch_822.json
# Loading ../data/saq/products/batch_823.json
# Loading ../data/saq/products/batch_824.json
# Loading ../data/saq/products/batch_825.json
# Loading ../data/saq/products/batch_826.json
# Loading ../data/saq/products/batch_827.json
# Loading ../data/saq/products/batch_828.json
# Loading ../data/saq/products/batch_829.json
# Loading ../data/saq/products/batch_830.json
# Loading ../data/saq/products/batch_831.json
# Loading ../data/saq/products/batch_832.json
# Loading ../data/saq/products/batch_833.json
# Loading ../data/saq/products/batch_834.json
# Loading ../data/saq/products/batch_835.json
# Loading ../data/saq/products/batch_836.json
# Loading ../data/saq/products/batch_837.json
# Loading ../data/saq/products/batch_838.json
# Loading ../data/saq/products/batch_839.json
# Loading ../data/saq/products/batch_840.json
# Loading ../data/saq/products/batch_841.json
# Loading ../data/saq/products/batch_842.json
# Loading ../data/saq/products/batch_843.json
# Loading ../data/saq/products/batch_844.json
# Loading ../data/saq/products/batch_845.json
# Loading ../data/saq/products/batch_846.json
# Loading ../data/saq/products/batch_847.json
# Loading ../data/saq/products/batch_848.json
# Loading ../data/saq/products/batch_849.json
# Loading ../data/saq/products/batch_850.json
# Loading ../data/saq/products/batch_851.json
# Loading ../data/saq/products/batch_852.json
# Loading ../data/saq/products/batch_853.json
# Loading ../data/saq/products/batch_854.json
# Loading ../data/saq/products/batch_855.json
# Loading ../data/saq/products/batch_856.json
# Loading ../data/saq/products/batch_857.json
# Loading ../data/saq/products/batch_858.json
# Loading ../data/saq/products/batch_859.json
# Loading ../data/saq/products/batch_860.json
# Loading ../data/saq/products/batch_861.json
# Loading ../data/saq/products/batch_862.json
# Loading ../data/saq/products/batch_863.json
# Loading ../data/saq/products/batch_864.json
# Loading ../data/saq/products/batch_865.json
# Loading ../data/saq/products/batch_866.json
# Loading ../data/saq/products/batch_867.json
# Loading ../data/saq/products/batch_868.json
# Loading ../data/saq/products/batch_869.json
# Loading ../data/saq/products/batch_870.json
# Loading ../data/saq/products/batch_871.json
# Loading ../data/saq/products/batch_872.json
# Loading ../data/saq/products/batch_873.json
# Loading ../data/saq/products/batch_874.json
# Loading ../data/saq/products/batch_875.json
# Loading ../data/saq/products/batch_876.json
# Loading ../data/saq/products/batch_877.json
# Loading ../data/saq/products/batch_878.json
# Loading ../data/saq/products/batch_879.json
# Loading ../data/saq/products/batch_880.json
# Loading ../data/saq/products/batch_881.json
# Loading ../data/saq/products/batch_882.json
# Loading ../data/saq/products/batch_883.json
# Loading ../data/saq/products/batch_884.json
# Loading ../data/saq/products/batch_885.json
# Loading ../data/saq/products/batch_886.json
# Loading ../data/saq/products/batch_887.json
# Loading ../data/saq/products/batch_888.json
# Loading ../data/saq/products/batch_889.json
# Loading ../data/saq/products/batch_890.json
# Loading ../data/saq/products/batch_891.json
# Loading ../data/saq/products/batch_892.json
# Loading ../data/saq/products/batch_893.json
# Loading ../data/saq/products/batch_894.json
# Loading ../data/saq/products/batch_895.json
# Loading ../data/saq/products/batch_896.json
# Loading ../data/saq/products/batch_897.json
# Loading ../data/saq/products/batch_898.json
# Loading ../data/saq/products/batch_899.json
# Loading ../data/saq/products/batch_900.json
# Loading ../data/saq/products/batch_901.json
# Loading ../data/saq/products/batch_902.json
# Loading ../data/saq/products/batch_903.json
# Loading ../data/saq/products/batch_904.json
# Loading ../data/saq/products/batch_905.json
# Loading ../data/saq/products/batch_906.json
# Loading ../data/saq/products/batch_907.json
# Loading ../data/saq/products/batch_908.json
# Loading ../data/saq/products/batch_909.json
# Loading ../data/saq/products/batch_910.json
# Loading ../data/saq/products/batch_911.json
# Loading ../data/saq/products/batch_912.json
# Loading ../data/saq/products/batch_913.json
# Loading ../data/saq/products/batch_914.json
# Loading ../data/saq/products/batch_915.json
# Loading ../data/saq/products/batch_916.json
# Loading ../data/saq/products/batch_917.json
# Loading ../data/saq/products/batch_918.json
# Loading ../data/saq/products/batch_919.json
# Loading ../data/saq/products/batch_920.json
# Loading ../data/saq/products/batch_921.json
# Loading ../data/saq/products/batch_922.json
# Loading ../data/saq/products/batch_923.json
# Loading ../data/saq/products/batch_924.json
# Loading ../data/saq/products/batch_925.json
# Loading ../data/saq/products/batch_926.json
# Loading ../data/saq/products/batch_927.json
# Loading ../data/saq/products/batch_928.json
# Loading ../data/saq/products/batch_929.json
# Loading ../data/saq/products/batch_930.json
# Loading ../data/saq/products/batch_931.json
# Loading ../data/saq/products/batch_932.json
# Loading ../data/saq/products/batch_933.json
# Loading ../data/saq/products/batch_934.json
# Loading ../data/saq/products/batch_935.json
# Loading ../data/saq/products/batch_936.json
# Loading ../data/saq/products/batch_937.json
# Loading ../data/saq/products/batch_938.json
# Loading ../data/saq/products/batch_939.json
# Loading ../data/saq/products/batch_940.json
# Loading ../data/saq/products/batch_941.json
# Loading ../data/saq/products/batch_942.json
# Loading ../data/saq/products/batch_943.json
# Loading ../data/saq/products/batch_944.json
# Loading ../data/saq/products/batch_945.json
# Loading ../data/saq/products/batch_946.json
# Loading ../data/saq/products/batch_947.json
# Loading ../data/saq/products/batch_948.json
# Loading ../data/saq/products/batch_949.json
# Loading ../data/saq/products/batch_950.json
# Loading ../data/saq/products/batch_951.json
# Loading ../data/saq/products/batch_952.json
# Loading ../data/saq/products/batch_953.json
# Loading ../data/saq/products/batch_954.json
# Loading ../data/saq/products/batch_955.json
# Loading ../data/saq/products/batch_956.json
# Loading ../data/saq/products/batch_957.json
# Loading ../data/saq/products/batch_958.json
# Loading ../data/saq/products/batch_959.json
# Loading ../data/saq/products/batch_960.json
# Loading ../data/saq/products/batch_961.json
# Loading ../data/saq/products/batch_962.json
# Loading ../data/saq/products/batch_963.json
# Loading ../data/saq/products/batch_964.json
# Loading ../data/saq/products/batch_965.json
# Loading ../data/saq/products/batch_966.json
# Loading ../data/saq/products/batch_967.json
# Loading ../data/saq/products/batch_968.json
# Loading ../data/saq/products/batch_969.json
# Loading ../data/saq/products/batch_970.json
# Loading ../data/saq/products/batch_971.json
# Loading ../data/saq/products/batch_972.json
# Loading ../data/saq/products/batch_973.json
# Loading ../data/saq/products/batch_974.json
# Loading ../data/saq/products/batch_975.json
# Loading ../data/saq/products/batch_976.json
# Loading ../data/saq/products/batch_977.json
# Loading ../data/saq/products/batch_978.json
# Loading ../data/saq/products/batch_979.json
# Loading ../data/saq/products/batch_980.json
# Loading ../data/saq/products/batch_981.json
# Loading ../data/saq/products/batch_982.json
# Loading ../data/saq/products/batch_983.json
# Loading ../data/saq/products/batch_984.json
# Loading ../data/saq/products/batch_985.json
# Loading ../data/saq/products/batch_986.json
# Loading ../data/saq/products/batch_987.json
# Loading ../data/saq/products/batch_988.json
# Loading ../data/saq/products/batch_989.json
# Loading ../data/saq/products/batch_990.json
# Loading ../data/saq/products/batch_991.json
# Loading ../data/saq/products/batch_992.json
# Loading ../data/saq/products/batch_993.json
# Loading ../data/saq/products/batch_994.json
# Loading ../data/saq/products/batch_995.json
# Loading ../data/saq/products/batch_996.json
# Loading ../data/saq/products/batch_997.json
# Loading ../data/saq/products/batch_998.json
# Loading ../data/saq/products/batch_999.json
# Loading ../data/saq/products/batch_1000.json
# Loading ../data/saq/products/batch_1001.json
# Loading ../data/saq/products/batch_1002.json
# Loading ../data/saq/products/batch_1003.json
# Loading ../data/saq/products/batch_1004.json
# Loading ../data/saq/products/batch_1005.json
# Loading ../data/saq/products/batch_1006.json
# Loading ../data/saq/products/batch_1007.json
# Loading ../data/saq/products/batch_1008.json
# Loading ../data/saq/products/batch_1009.json
# Loading ../data/saq/products/batch_1010.json
# Loading ../data/saq/products/batch_1011.json
# Loading ../data/saq/products/batch_1012.json
# Loading ../data/saq/products/batch_1013.json
# Loading ../data/saq/products/batch_1014.json
# Loading ../data/saq/products/batch_1015.json
# Loading ../data/saq/products/batch_1016.json
# Loading ../data/saq/products/batch_1017.json
# Loading ../data/saq/products/batch_1018.json
# Loading ../data/saq/products/batch_1019.json
# Loading ../data/saq/products/batch_1020.json
# Loading ../data/saq/products/batch_1021.json
# Loading ../data/saq/products/batch_1022.json
# Loading ../data/saq/products/batch_1023.json
# Loading ../data/saq/products/batch_1024.json
# Loading ../data/saq/products/batch_1025.json
# Loading ../data/saq/products/batch_1026.json
# Loading ../data/saq/products/batch_1027.json
# Loading ../data/saq/products/batch_1028.json
# Loading ../data/saq/products/batch_1029.json
# Loading ../data/saq/products/batch_1030.json
# Loading ../data/saq/products/batch_1031.json
# Loading ../data/saq/products/batch_1032.json
# Loading ../data/saq/products/batch_1033.json
# Loading ../data/saq/products/batch_1034.json
# Loading ../data/saq/products/batch_1035.json
# Loading ../data/saq/products/batch_1036.json
# Loading ../data/saq/products/batch_1037.json
# Loading ../data/saq/products/batch_1038.json
# Loading ../data/saq/products/batch_1039.json
# Loading ../data/saq/products/batch_1040.json
# Loading ../data/saq/products/batch_1041.json
# Loading ../data/saq/products/batch_1042.json
# Loading ../data/saq/products/batch_1043.json
# Loading ../data/saq/products/batch_1044.json
# Loading ../data/saq/products/batch_1045.json
# Loading ../data/saq/products/batch_1046.json
# Loading ../data/saq/products/batch_1047.json
# Loading ../data/saq/products/batch_1048.json
# Loading ../data/saq/products/batch_1049.json
# Loading ../data/saq/products/batch_1050.json
# Loading ../data/saq/products/batch_1051.json
# Loading ../data/saq/products/batch_1052.json
# Loading ../data/saq/products/batch_1053.json
# Loading ../data/saq/products/batch_1054.json
# Loading ../data/saq/products/batch_1055.json
# Loading ../data/saq/products/batch_1056.json
# Loading ../data/saq/products/batch_1057.json
# Loading ../data/saq/products/batch_1058.json
# Loading ../data/saq/products/batch_1059.json
# Loading ../data/saq/products/batch_1060.json
# Loading ../data/saq/products/batch_1061.json
# Loading ../data/saq/products/batch_1062.json
# Loading ../data/saq/products/batch_1063.json
# Loading ../data/saq/products/batch_1064.json
# Loading ../data/saq/products/batch_1065.json
# Loading ../data/saq/products/batch_1066.json
# Loading ../data/saq/products/batch_1067.json
# Loading ../data/saq/products/batch_1068.json
# Loading ../data/saq/products/batch_1069.json
# Loading ../data/saq/products/batch_1070.json
# Loading ../data/saq/products/batch_1071.json
# Loading ../data/saq/products/batch_1072.json
# Loading ../data/saq/products/batch_1073.json
# Loading ../data/saq/products/batch_1074.json
# Loading ../data/saq/products/batch_1075.json
# Loading ../data/saq/products/batch_1076.json
# Loading ../data/saq/products/batch_1077.json
# Loading ../data/saq/products/batch_1078.json
# Loading ../data/saq/products/batch_1079.json
# Loading ../data/saq/products/batch_1080.json
# Loading ../data/saq/products/batch_1081.json
# Loading ../data/saq/products/batch_1082.json
# Loading ../data/saq/products/batch_1083.json
# Loading ../data/saq/products/batch_1084.json
# Loading ../data/saq/products/batch_1085.json
# Loading ../data/saq/products/batch_1086.json
# Loading ../data/saq/products/batch_1087.json
# Loading ../data/saq/products/batch_1088.json
# Loading ../data/saq/products/batch_1089.json
# Loading ../data/saq/products/batch_1090.json
# Loading ../data/saq/products/batch_1091.json
# ...
# Loading ../data/saq/products/batch_1642.json
# Loading ../data/saq/products/batch_1643.json
# Loading ../data/saq/products/batch_1644.json
# Loading ../data/saq/products/batch_1645.json
# Loading ../data/saq/products/batch_1646.json
# Loading ../data/saq/products/batch_1647.json
# Loading ../data/saq/products/batch_1648.json
# Loading ../data/saq/products/batch_1649.json
# Loading ../data/saq/products/batch_1650.json
# Loading ../data/saq/products/batch_1651.json
# Loading ../data/saq/products/batch_1652.json
# Loading ../data/saq/products/batch_1653.json
# Loading ../data/saq/products/batch_1654.json
# Loading ../data/saq/products/batch_1655.json
# Loading ../data/saq/products/batch_1656.json
# Loading ../data/saq/products/batch_1657.json
# Loading ../data/saq/products/batch_1658.json
# Loading ../data/saq/products/batch_1659.json
# Loading ../data/saq/products/batch_1660.json
# Loading ../data/saq/products/batch_1661.json
# Loading ../data/saq/products/batch_1662.json
# Loading ../data/saq/products/batch_1663.json
# Loading ../data/saq/products/batch_1664.json
# Loading ../data/saq/products/batch_1665.json
# Loading ../data/saq/products/batch_1666.json
# Loading ../data/saq/products/batch_1667.json
# Loading ../data/saq/products/batch_1668.json
# Loading ../data/saq/products/batch_1669.json
# Loading ../data/saq/products/batch_1670.json
# Loading ../data/saq/products/batch_1671.json
# Loading ../data/saq/products/batch_1672.json
# Loading ../data/saq/products/batch_1673.json
# Loading ../data/saq/products/batch_1674.json
# Loading ../data/saq/products/batch_1675.json
# Loading ../data/saq/products/batch_1676.json
# Loading ../data/saq/products/batch_1677.json
# Loading ../data/saq/products/batch_1678.json
# Loading ../data/saq/products/batch_1679.json
# Loading ../data/saq/products/batch_1680.json
# Loading ../data/saq/products/batch_1681.json
# Loading ../data/saq/products/batch_1682.json
# Loading ../data/saq/products/batch_1683.json
# Loading ../data/saq/products/batch_1684.json
# Loading ../data/saq/products/batch_1685.json
# Loading ../data/saq/products/batch_1686.json
# Loading ../data/saq/products/batch_1687.json
# Loading ../data/saq/products/batch_1688.json
# Loading ../data/saq/products/batch_1689.json
# Loading ../data/saq/products/batch_1690.json
# Loading ../data/saq/products/batch_1691.json
# Loading ../data/saq/products/batch_1692.json
# Loading ../data/saq/products/batch_1693.json
# Loading ../data/saq/products/batch_1694.json
# Loading ../data/saq/products/batch_1695.json
# Loading ../data/saq/products/batch_1696.json
# Loading ../data/saq/products/batch_1697.json
# Loading ../data/saq/products/batch_1698.json
# Loading ../data/saq/products/batch_1699.json
# Loading ../data/saq/products/batch_1700.json
# Loading ../data/saq/products/batch_1701.json
# Loading ../data/saq/products/batch_1702.json
# Loading ../data/saq/products/batch_1703.json
# Loading ../data/saq/products/batch_1704.json
# Loading ../data/saq/products/batch_1705.json
# Loading ../data/saq/products/batch_1706.json
# Loading ../data/saq/products/batch_1707.json
# Loading ../data/saq/products/batch_1708.json
# Loading ../data/saq/products/batch_1709.json
# Loading ../data/saq/products/batch_1710.json
# Loading ../data/saq/products/batch_1711.json
# Loading ../data/saq/products/batch_1712.json
# Loading ../data/saq/products/batch_1713.json
# Loading ../data/saq/products/batch_1714.json
# Loading ../data/saq/products/batch_1715.json
# Loading ../data/saq/products/batch_1716.json
# Loading ../data/saq/products/batch_1717.json
# Loading ../data/saq/products/batch_1718.json
# Loading ../data/saq/products/batch_1719.json
# Loading ../data/saq/products/batch_1720.json
# Loading ../data/saq/products/batch_1721.json
# Loading ../data/saq/products/batch_1722.json
# Loading ../data/saq/products/batch_1723.json
# Loading ../data/saq/products/batch_1724.json
# Loading ../data/saq/products/batch_1725.json
# Loading ../data/saq/products/batch_1726.json
# Loading ../data/saq/products/batch_1727.json
# Loading ../data/saq/products/batch_1728.json
# Loading ../data/saq/products/batch_1729.json
# Loading ../data/saq/products/batch_1730.json
# Loading ../data/saq/products/batch_1731.json
# Loading ../data/saq/products/batch_1732.json
# Loading ../data/saq/products/batch_1733.json
# Loading ../data/saq/products/batch_1734.json
# Loading ../data/saq/products/batch_1735.json
# Loading ../data/saq/products/batch_1736.json
# Loading ../data/saq/products/batch_1737.json
# Loading ../data/saq/products/batch_1738.json
# Loading ../data/saq/products/batch_1739.json
# Loading ../data/saq/products/batch_1740.json
# Loading ../data/saq/products/batch_1741.json
# Loading ../data/saq/products/batch_1742.json
# Loading ../data/saq/products/batch_1743.json
# Loading ../data/saq/products/batch_1744.json
# Loading ../data/saq/products/batch_1745.json
# Loading ../data/saq/products/batch_1746.json
# Loading ../data/saq/products/batch_1747.json
# Loading ../data/saq/products/batch_1748.json
# Loading ../data/saq/products/batch_1749.json
# Loading ../data/saq/products/batch_1750.json
# Loading ../data/saq/products/batch_1751.json
# Loading ../data/saq/products/batch_1752.json
# Loading ../data/saq/products/batch_1753.json
# Loading ../data/saq/products/batch_1754.json
# Loading ../data/saq/products/batch_1755.json
# Loading ../data/saq/products/batch_1756.json
# Loading ../data/saq/products/batch_1757.json
# Loading ../data/saq/products/batch_1758.json
# Loading ../data/saq/products/batch_1759.json
# Loading ../data/saq/products/batch_1760.json
# Loading ../data/saq/products/batch_1761.json
# Loading ../data/saq/products/batch_1762.json
# Loading ../data/saq/products/batch_1763.json
# Loading ../data/saq/products/batch_1764.json
# Loading ../data/saq/products/batch_1765.json
# Loading ../data/saq/products/batch_1766.json
# Loading ../data/saq/products/batch_1767.json
# Loading ../data/saq/products/batch_1768.json
# Loading ../data/saq/products/batch_1769.json
# Loading ../data/saq/products/batch_1770.json
# Loading ../data/saq/products/batch_1771.json
# Loading ../data/saq/products/batch_1772.json
# Loading ../data/saq/products/batch_1773.json
# Loading ../data/saq/products/batch_1774.json
# Loading ../data/saq/products/batch_1775.json
# Loading ../data/saq/products/batch_1776.json
# Loading ../data/saq/products/batch_1777.json
# Loading ../data/saq/products/batch_1778.json
# Loading ../data/saq/products/batch_1779.json
# Loading ../data/saq/products/batch_1780.json
# Loading ../data/saq/products/batch_1781.json
# Loading ../data/saq/products/batch_1782.json
# Loading ../data/saq/products/batch_1783.json
# Loading ../data/saq/products/batch_1784.json
# Loading ../data/saq/products/batch_1785.json
# Loading ../data/saq/products/batch_1786.json
# Loading ../data/saq/products/batch_1787.json
# Loading ../data/saq/products/batch_1788.json
# Loading ../data/saq/products/batch_1789.json
# Loading ../data/saq/products/batch_1790.json
# Loading ../data/saq/products/batch_1791.json
# Loading ../data/saq/products/batch_1792.json
# Loading ../data/saq/products/batch_1793.json
# Loading ../data/saq/products/batch_1794.json
# Loading ../data/saq/products/batch_1795.json
# Loading ../data/saq/products/batch_1796.json
# Loading ../data/saq/products/batch_1797.json
# Loading ../data/saq/products/batch_1798.json
# Loading ../data/saq/products/batch_1799.json
# Loading ../data/saq/products/batch_1800.json
# Loading ../data/saq/products/batch_1801.json
# Loading ../data/saq/products/batch_1802.json
# Loading ../data/saq/products/batch_1803.json
# Loading ../data/saq/products/batch_1804.json
# Loading ../data/saq/products/batch_1805.json
# Loading ../data/saq/products/batch_1806.json
# Loading ../data/saq/products/batch_1807.json
# Loading ../data/saq/products/batch_1808.json
# Loading ../data/saq/products/batch_1809.json
# Loading ../data/saq/products/batch_1810.json
# Loading ../data/saq/products/batch_1811.json
# Loading ../data/saq/products/batch_1812.json
# Loading ../data/saq/products/batch_1813.json
# Loading ../data/saq/products/batch_1814.json
# Loading ../data/saq/products/batch_1815.json
# Loading ../data/saq/products/batch_1816.json
# Loading ../data/saq/products/batch_1817.json
# Loading ../data/saq/products/batch_1818.json
# Loading ../data/saq/products/batch_1819.json
# Loading ../data/saq/products/batch_1820.json
# Loading ../data/saq/products/batch_1821.json
# Loading ../data/saq/products/batch_1822.json
# Loading ../data/saq/products/batch_1823.json
# Loading ../data/saq/products/batch_1824.json
# Loading ../data/saq/products/batch_1825.json
# Loading ../data/saq/products/batch_1826.json
# Loading ../data/saq/products/batch_1827.json
# Loading ../data/saq/products/batch_1828.json
# Loading ../data/saq/products/batch_1829.json
# Loading ../data/saq/products/batch_1830.json
# Loading ../data/saq/products/batch_1831.json
# Loading ../data/saq/products/batch_1832.json
# Loading ../data/saq/products/batch_1833.json
# Loading ../data/saq/products/batch_1834.json
# Loading ../data/saq/products/batch_1835.json
# Loading ../data/saq/products/batch_1836.json
# Loading ../data/saq/products/batch_1837.json
# Loading ../data/saq/products/batch_1838.json
# Loading ../data/saq/products/batch_1839.json
# Loading ../data/saq/products/batch_1840.json
# Loading ../data/saq/products/batch_1841.json
# Loading ../data/saq/products/batch_1842.json
# Loading ../data/saq/products/batch_1843.json
# Loading ../data/saq/products/batch_1844.json
# Loading ../data/saq/products/batch_1845.json
# Loading ../data/saq/products/batch_1846.json
# Loading ../data/saq/products/batch_1847.json
# Loading ../data/saq/products/batch_1848.json
# Loading ../data/saq/products/batch_1849.json
# Loading ../data/saq/products/batch_1850.json
# Loading ../data/saq/products/batch_1851.json
# Loading ../data/saq/products/batch_1852.json
# Loading ../data/saq/products/batch_1853.json
# Loading ../data/saq/products/batch_1854.json
# Loading ../data/saq/products/batch_1855.json
# Loading ../data/saq/products/batch_1856.json
# Loading ../data/saq/products/batch_1857.json
# Loading ../data/saq/products/batch_1858.json
# Loading ../data/saq/products/batch_1859.json
# Loading ../data/saq/products/batch_1860.json
# Loading ../data/saq/products/batch_1861.json
# Loading ../data/saq/products/batch_1862.json
# Loading ../data/saq/products/batch_1863.json
# Loading ../data/saq/products/batch_1864.json
# Loading ../data/saq/products/batch_1865.json
# Loading ../data/saq/products/batch_1866.json
# Loading ../data/saq/products/batch_1867.json
# Loading ../data/saq/products/batch_1868.json
# Loading ../data/saq/products/batch_1869.json
# Loading ../data/saq/products/batch_1870.json
# Loading ../data/saq/products/batch_1871.json
# Loading ../data/saq/products/batch_1872.json
# Loading ../data/saq/products/batch_1873.json
# Loading ../data/saq/products/batch_1874.json
# Loading ../data/saq/products/batch_1875.json
# Loading ../data/saq/products/batch_1876.json
# Loading ../data/saq/products/batch_1877.json
# Loading ../data/saq/products/batch_1878.json
# Loading ../data/saq/products/batch_1879.json
# Loading ../data/saq/products/batch_1880.json
# Loading ../data/saq/products/batch_1881.json
# Loading ../data/saq/products/batch_1882.json
# Loading ../data/saq/products/batch_1883.json
# Loading ../data/saq/products/batch_1884.json
# Loading ../data/saq/products/batch_1885.json
# Loading ../data/saq/products/batch_1886.json
# Loading ../data/saq/products/batch_1887.json
# Loading ../data/saq/products/batch_1888.json
# Loading ../data/saq/products/batch_1889.json
# Loading ../data/saq/products/batch_1890.json
# Loading ../data/saq/products/batch_1891.json
# Loading ../data/saq/products/batch_1892.json
# Loading ../data/saq/products/batch_1893.json
# Loading ../data/saq/products/batch_1894.json
# Loading ../data/saq/products/batch_1895.json
# Loading ../data/saq/products/batch_1896.json
# Loading ../data/saq/products/batch_1897.json
# Loading ../data/saq/products/batch_1898.json
# Loading ../data/saq/products/batch_1899.json
# Loading ../data/saq/products/batch_1900.json
# Loading ../data/saq/products/batch_1901.json
# Loading ../data/saq/products/batch_1902.json
# Loading ../data/saq/products/batch_1903.json
# Loading ../data/saq/products/batch_1904.json
# Loading ../data/saq/products/batch_1905.json
# Loading ../data/saq/products/batch_1906.json
# Loading ../data/saq/products/batch_1907.json
# /tmp/ipykernel_3972084/1430770659.py:50: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return pd.concat(data, ignore_index=True)
#                                url  \
# 0  https://www.saq.com/fr/14099363
# 1  https://www.saq.com/fr/14099371
# 2  https://www.saq.com/fr/14099380
# 3  https://www.saq.com/fr/14099398
# 4  https://www.saq.com/fr/14113541
#
#                                         product_name   price  \
# 0  Domaine François Raveneau Chablis Premier Cru ...   83.75
# 1             Domaine François Raveneau Chablis 2015   56.00
# 2             Domaine François Raveneau Chablis 2016   56.00
# 3  Domaine François Raveneau Chablis Grand Cru Le...  126.50
# 4  Domaine François Raveneau Chablis Premier Cru ...   83.75
#
#                    breadcrumb product_details_pays  \
# 0  Produits > Vin > Vin blanc               France
# 1  Produits > Vin > Vin blanc               France
# 2  Produits > Vin > Vin blanc               France
# 3  Produits > Vin > Vin blanc               France
# 4  Produits > Vin > Vin blanc               France
#
#                   product_details_region product_details_appellation  \
# 0  Bourgogne, Chablis et Grand Auxerrois         Chablis Premier Cru
# 1  Bourgogne, Chablis et Grand Auxerrois                     Chablis
# 2  Bourgogne, Chablis et Grand Auxerrois                     Chablis
# 3  Bourgogne, Chablis et Grand Auxerrois           Chablis Grand Cru
# 4  Bourgogne, Chablis et Grand Auxerrois         Chablis Premier Cru
#
#                         product_details_designation product_details_cepage  \
# 0  (AOC/AOP) Appellation origine controlée/protégée       Chardonnay 100 %
# 1  (AOC/AOP) Appellation origine controlée/protégée       Chardonnay 100 %
# 2  (AOC/AOP) Appellation origine controlée/protégée       Chardonnay 100 %
# 3  (AOC/AOP) Appellation origine controlée/protégée       Chardonnay 100 %
# 4  (AOC/AOP) Appellation origine controlée/protégée       Chardonnay 100 %
#
#   product_details_degre_alcool product_details_couleur product_details_format  \
# 0                         13 %                   Blanc                 750 ml
# 1                         13 %                   Blanc                 750 ml
# 2                         13 %                   Blanc                 750 ml
# 3                         13 %                   Blanc                 750 ml
# 4                         13 %                   Blanc                 750 ml
#
#   product_details_producteur product_details_agent product_details_code_saq  \
# 0  Domaine François Raveneau         Oenopole Inc.                 14099363
# 1  Domaine François Raveneau         Oenopole Inc.                 14099371
# 2  Domaine François Raveneau         Oenopole Inc.                 14099380
# 3  Domaine François Raveneau         Oenopole Inc.                 14099398
# 4  Domaine François Raveneau         Oenopole Inc.                 14113541
#
#   product_details_code_cup product_details_tasting_notes  \
# 0           04000140993633                            {}
# 1           04000140993718                            {}
# 2           04000140993800                            {}
# 3           04000140993985                            {}
# 4           04000141135414                            {}
#
#   product_details_pairings                                    product_details
# 0                       []  {'Pays': 'France', 'Région': 'Bourgogne, Chabl...
# 1                       []  {'Pays': 'France', 'Région': 'Bourgogne, Chabl...
# 2                       []  {'Pays': 'France', 'Région': 'Bourgogne, Chabl...
# 3                       []  {'Pays': 'France', 'Région': 'Bourgogne, Chabl...
# 4                       []  {'Pays': 'France', 'Région': 'Bourgogne, Chabl...

# %%
len(df)
# Out:
# 37086

# %% [markdown]
# # Insert subcategories

# %%
conn = psycopg2.connect(DB_URL)

# %%
dfbeers = df[df['breadcrumb'].str.startswith("Produits > Bière", na=False)].copy()
# dfbeers = df[df['product_name'].str.contains("Heineken", na=False)].copy()

# %%
# check if breadcrumb contains "Bière"

# %%
print(len(dfbeers))

dfbeers['breadcrumb']
# Out:
# 330
# 235           Produits > Bière > Bière ambrée > Bière ale
# 236          Produits > Bière > Bière blanche > Bière ale
# 237         Produits > Bière > Bière blonde > Bière lager
# 319      Produits > Bière > Bière dorée > Bière spontanée
# 320            Produits > Bière > Bière noire > Bière ale
#                                ...
# 37124         Produits > Bière > Bière blonde > Bière ale
# 37464          Produits > Bière > Bière noire > Bière ale
# 37889         Produits > Bière > Bière blonde > Bière ale
# 38043          Produits > Bière > Bière rosée > Bière ale
# 38119    Produits > Bière > Bière rouge > Bière spontanée
# Name: breadcrumb, Length: 330, dtype: object

# %%
# for each row in dfwines, query table subcategory2 and category to check if (dfwine['product_details_couleur'] = category.category_name_fr   
# and dfwine['product_details_appellation'] = subcategory2.subcategory_name_fr)
# SELECT count(1) from subcategory2, category where subcategory2.category_id = category.category_id and subcategory2.subcategory_name_fr = dfwine['product_details_appellation'] and category.category_name_fr = dfwine['product_details_couleur']
from uuid import uuid4


def update_subcategories(conn, dfwines):
    cursor = conn.cursor()
    print("Connection opened")

    SELECT_COUNT_SQL = """
        SELECT count(1)
        FROM subcategory2
        JOIN category ON subcategory2.category_id = category.category_id
        WHERE subcategory2.subcategory_name_fr = %s
        AND category.category_name_fr = %s
    """
    
    SELECT_CATEGORY_SQL = "SELECT category_id FROM category WHERE category_name_fr = %s"
    SELECT_MAX_CODE_SQL = """
        SELECT MAX(subcategory_code)
        FROM subcategory2
        WHERE subcategory_code > 810000000 AND subcategory_code < 820000000
    """
    
    INSERT_SUBCATEGORY_SQL = """
        INSERT INTO subcategory2 (subcategory_id, subcategory_code, subcategory_name_fr, subcategory_name_en, category_id)
        VALUES (%s, %s, %s, %s, %s)
    """

    for _, row in dfwines.iterrows():
        appellation = row.get('product_details_appellation') or "None"
        couleur = row.get('product_details_couleur') or "None"

        try:
            cursor.execute(SELECT_COUNT_SQL, (appellation, couleur))
            if cursor.fetchone()[0]:
                #print(f"Found: {appellation} - {couleur}")
                continue

            print(f"Not found: {appellation} - {couleur}")
            cursor.execute(SELECT_CATEGORY_SQL, (couleur,))
            cat_result = cursor.fetchone()
            if not cat_result:
                print(f"Category not found for: {couleur}")
                continue

            category_id = cat_result[0]
            cursor.execute(SELECT_MAX_CODE_SQL)
            max_code = cursor.fetchone()[0] or 810000000
            subcategory_code = max_code + 1

            subcategory_id = str(uuid4())
            cursor.execute(INSERT_SUBCATEGORY_SQL, (
                subcategory_id, subcategory_code, appellation, appellation, category_id
            ))
            conn.commit()
            #print(f"Inserted: {appellation} with ID {subcategory_id}")

        except Exception as e:
            print(f"Error: {e}")
            conn.rollback()
    cursor.close()

# %%
conn = psycopg2.connect(DB_URL)
try: 
    update_subcategories(conn, dfwines)
except Exception as e:
    print(f"Error: {e}")
finally:
    conn.close()

# %% [markdown]
# # Step 2 insert into products

# %%
import psycopg2
DB_URL = "postgresql://postgres.oqvdwtiwrzyjpnouwxch:f87JpR9Uvud6NR3HwbP@aws-0-ca-central-1.pooler.supabase.com:5432/postgres"

conn = psycopg2.connect(DB_URL)

# %%
import os
import json
from uuid import uuid4
from datetime import datetime, timezone
from tqdm import tqdm

def get_or_generate_upc(cursor, row, log_file):
    product_upc = row.get('product_details_code_cup') or "8888"
    product_name = row.get('product_name')

    if product_upc != "8888" or not product_name:
        return product_upc

    cursor.execute("SELECT product_upc FROM product WHERE product_name_fr = %s", (product_name,))
    result = cursor.fetchone()

    if result:
        return result[0]

    log_file.write(f"UPC not found for {product_name}, generating new one.\n")
    cursor.execute("SELECT nextval('octo_upc')")
    new_upc = str(cursor.fetchone()[0])
    log_file.write(f"Generated UPC: {new_upc} for {product_name}\n")
    return new_upc

def get_subcategory_id(cursor, row):
    cursor.execute("""
        SELECT s.subcategory_id
        FROM subcategory2 s
        JOIN category c ON s.category_id = c.category_id
        JOIN family f ON f.family_id = c.family_id
        WHERE f.family_name_fr = 'Vin'
          AND c.category_name_fr = %s
          AND s.subcategory_name_fr = %s
    """, (
        row.get('product_details_couleur') or "None",
        row.get('product_details_appellation') or "None"
    ))
    result = cursor.fetchone()
    return result[0] if result else None

def upsert_wines(df, conn):
    df['product_id'] = None
    df['product_upc'] = None

    cursor = conn.cursor()
    os.makedirs("../logs", exist_ok=True)
    log_file = open("../logs/insert_reject.log", "a")

    wines = df[df['breadcrumb'].str.startswith("Produits > Vin", na=False)].copy()
    wines['product_details_couleur'] = wines['product_details_couleur'].str.strip()

    for idx in tqdm(wines.index, total=len(wines), desc="Upserting wines"):
        row = df.loc[idx]
        product_name = row.get('product_name')
        if not product_name:
            log_file.write(f"Product name is empty for index {idx}\n")
            continue
        product_id = None
        product_upc = None
        subcategory_id = None
        details_json = None

        try:
            df.at[idx, 'product_details_appellation'] = row.get('product_details_appellation') or "None"
            df.at[idx, 'product_details_couleur'] = row.get('product_details_couleur') or "None"

            product_upc = get_or_generate_upc(cursor, row, log_file)
            df.at[idx, 'product_upc'] = product_upc

            cursor.execute("SELECT 1 FROM product WHERE product_upc = %s", (product_upc,))
            if cursor.fetchone():
                continue

            subcategory_id = get_subcategory_id(cursor, row)
            if not subcategory_id:
                log_file.write(f"Subcategory not found for {row['product_details_couleur']} - {row['product_details_appellation']}\n")
                continue

            product_id = str(uuid4())
            df.at[idx, 'product_id'] = product_id

            details_json = json.dumps(row['product_details'], default=str)
            now = datetime.now(timezone.utc).isoformat()

            cursor.execute("""
                INSERT INTO product (
                    product_id, product_name_fr, product_name_en, product_name_es,
                    product_upc, producer_code, subcategory_id, details,
                    unit_equivalence_qty, product_code, refresh_date
                )
                VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
            """, (
                product_id, product_name, product_name, product_name,
                product_upc, row.get('product_details_code_saq'),
                subcategory_id, details_json, 1, row.get('product_details_code_saq'),
                now
            ))
            conn.commit()

        except Exception as e:
            conn.rollback()
            log_file.write(f"{datetime.now()} Error inserting {product_name}: {e}\n")
            log_file.write(f"1: {product_id}, 5: {product_upc}, 7: {subcategory_id}, 8: {details_json}\n")

    log_file.close()
    cursor.close()

# %%
cursor.close()
conn.close()

# %%
conn = psycopg2.connect(DB_URL)
try: 
    upsert_wines(dfwines, conn)
except Exception as e:
    print(f"Error: {e}")
finally:
    conn.close()

# %%
dfwines.head()

# %% [markdown]
# # STEP 3 update Volumes

# %%
import psycopg2
DB_URL = "postgresql://postgres.oqvdwtiwrzyjpnouwxch:f87JpR9Uvud6NR3HwbP@aws-0-ca-central-1.pooler.supabase.com:5432/postgres"

conn = psycopg2.connect(DB_URL)

# %%
# import re
# from tqdm import tqdm

# def update_product_volumes(df, conn):
#     cursor = conn.cursor()

#     # Clean and filter rows with valid formats
#     df = df[df['product_details_format'].notnull()].copy()

#     for _, row in tqdm(df.iterrows(), total=len(df), desc="Updating volume & unit info"):
#         fmt = row['product_details_format'].replace(',', '.').strip()

#         # Match format like "750 ml", "1 L", "1.5 L", etc.
#         match = re.match(r'([\d\.]+)\s*([a-zA-Z]+)', fmt)
#         if not match:
#             print(f"Could not parse format: {fmt}")
#             continue

#         try:
#             volume_qty = float(match.group(1))
#             print(f"Parsed volume quantity: {volume_qty}")
#         except ValueError:
#             print(f"Invalid volume quantity: {match.group(1)}")
#             continue
#         unit = match.group(2).lower()

#         # Get lookup_id from measure_lkp
#         try:
#             cursor.execute("""
#                 SELECT lookup_id
#                 FROM measure_lkp
#                 WHERE lower(lookup_abbreviation_fr) = %s
#             """, (unit,))
#             result = cursor.fetchone()
#             if not result:
#                 print(f"No lookup_id found for unit: {unit}")
#                 continue

#             volume_equivalence_id = result[0]
#             fixed_unit_id = 'a9e5e8dd-098c-4f76-86f8-08f36620ac0c'  # fixed UUID

#             cursor.execute("""
#                 UPDATE product
#                 SET volume_equivalence_qty = %s,
#                     unit_equivalence_id = %s,
#                     volume_equivalence_id = %s
#                 WHERE product_upc = %s
#             """, (
#                 volume_qty,
#                 fixed_unit_id,
#                 volume_equivalence_id,
#                 row.get('product_details_code_cup')
#             ))
#             conn.commit()
#         except Exception as e:
#             conn.rollback()
#             print(f"Error updating {row.get('product_name', '')}: {e}")

#     cursor.close()

# %%
import re
import logging
from tqdm import tqdm

# configure logging once at top-level of your module
logging.basicConfig(
    filename="../logs/volume_updates.log",
    level=logging.INFO,
    format="%(asctime)s %(levelname)s %(message)s",
)

FORMAT_REGEX = re.compile(r"^\s*([\d.]+)\s*([A-Za-z]+)\s*$")
SELECT_LKP_SQL = """
    SELECT lookup_id
      FROM measure_lkp
     WHERE lower(lookup_abbreviation_fr) = %s
"""
UPDATE_PROD_SQL = """
    UPDATE product
       SET volume_equivalence_qty = %s,
           unit_equivalence_id     = %s,
           volume_equivalence_id   = %s
     WHERE product_upc = %s
"""

FIXED_UNIT_ID = "a9e5e8dd-098c-4f76-86f8-08f36620ac0c"

def update_product_volumes(df, conn):
    df = df[df["product_details_format"].notna()].copy()
    with conn.cursor() as cur:
        for _, row in tqdm(df.iterrows(), total=len(df), desc="Updating volumes"):
            fmt = row["product_details_format"].replace(",", ".")
            m = FORMAT_REGEX.match(fmt)
            if not m:
                logging.warning("Could not parse format: %r", fmt)
                continue

            qty_str, unit = m.groups()
            try:
                qty = float(qty_str)
            except ValueError:
                logging.warning("Invalid quantity %r in %r", qty_str, fmt)
                continue

            unit = unit.lower()
            cur.execute(SELECT_LKP_SQL, (unit,))
            lkp = cur.fetchone()
            if not lkp:
                logging.warning("No lookup_id for unit %r", unit)
                continue

            try:
                cur.execute(
                    UPDATE_PROD_SQL,
                    (qty, FIXED_UNIT_ID, lkp[0], row.get("product_details_code_cup")),
                )
                conn.commit()
            except Exception as e:
                conn.rollback()
                logging.error("Error updating %r: %s", row.get("product_name"), e)

# %%
conn = psycopg2.connect(DB_URL)
try: 
    update_product_volumes(dfwines, conn)
except Exception as e:
    print(f"Error: {e}")
finally:
    conn.close()

# %% [markdown]
# # --Step 4 insert product_sizes

# %%
import psycopg2
DB_URL = "postgresql://postgres.oqvdwtiwrzyjpnouwxch:f87JpR9Uvud6NR3HwbP@aws-0-ca-central-1.pooler.supabase.com:5432/postgres"

conn = psycopg2.connect(DB_URL)

# %%
# from uuid import uuid4

# def populate_product_sizes(df, conn):
#     cursor = conn.cursor()

#     for _, row in tqdm(df.iterrows(), total=len(df), desc="Populating product_size"):
#         upc = row.get("product_details_code_cup")

#         if not upc:
#             continue

#         try:
#             # Retrieve product info
#             cursor.execute("""
#                 SELECT product_id, product_upc,
#                     unit_equivalence_qty, unit_equivalence_id,   
#                     volume_equivalence_qty, volume_equivalence_id                           
#                 FROM product
#                 WHERE product_upc = %s
#             """, (upc,))
#             product = cursor.fetchone()

#             if not product:
#                 continue  # Product not found

#             product_id, db_upc, unit_qty, unit_id,  vol_qty, vol_eq_id = product

#             # Check if already exists for UPC
#             cursor.execute("SELECT 1 FROM product_sizes WHERE upc = %s", (upc,))
#             if cursor.fetchone():
#                 continue  # Already exists for this UPC

            
#             # Insert new entry
#             size_id = str(uuid4())
#             cursor.execute("""
#                 INSERT INTO product_sizes (
#                     product_size_id, product_id,
#                     upc,
#                     unit_equivalence_qty, unit_equivalence_id,
#                     volume_equivalence_measure_id, volume_equivalence_qty
#                 )
#                 VALUES (%s, %s, %s, %s, %s,%s, %s)
#             """, (
#                 size_id, product_id,
#                 upc,
#                 unit_qty, unit_id,
#                 vol_eq_id, vol_qty
#             ))
#             conn.commit()

#         except Exception as e:
#             conn.rollback()
#             print(f"Error inserting product_size for {row.get('product_name')}: {e}")

#     cursor.close()

# %%
# populate_product_sizes(df, conn)

# %% [markdown]
# # Insert package

# %%
import psycopg2
DB_URL = "postgresql://postgres.oqvdwtiwrzyjpnouwxch:f87JpR9Uvud6NR3HwbP@aws-0-ca-central-1.pooler.supabase.com:5432/postgres"

conn = psycopg2.connect(DB_URL)

# %%
from uuid import uuid4
from tqdm import tqdm


def get_distributor_id(conn, distributor_name):
    cursor = conn.cursor()
    try: 
        result = cursor.execute(f"SELECT distributor_id FROM distributor WHERE distributor_name_fr = '{distributor_name}'")
    except Exception as e:
        print(f"Error fetching distributor ID: {e}")
        distributor_id = None
        conn.rollback()
        cursor.close()
    result = cursor.fetchone()
    if result:
        distributor_id = result[0]
    else:
        print("Distributor not found")
        distributor_id = None
    cursor.close()
    return distributor_id

def not_exist_in_package(conn, product_id,  distributor_id):
    #print(f"Checking if product {product_id} exists in package for distributor {distributor_id}")
    cursor = conn.cursor()
    try:
        cursor.execute("SELECT 1 FROM package WHERE product_id = %s AND distributor_id = %s", (product_id, distributor_id))
        result = cursor.fetchone()
        return not result
        
    except Exception as e:
        print(f"Error checking package existence: {e}")
        return False
    finally:
        cursor.close()

def insert_package(conn, df, distibutor_name):

    SQL_CHECK_DIST_CODE = """
        SELECT distributor_code from package where distributor_code = %s
    """

    distributor_id = get_distributor_id(conn, distibutor_name)
    if not distributor_id:
        print("Distributor ID is None, skipping package insertion.")
        return
    
    
    cursor = conn.cursor()


    for _, row in tqdm(df.iterrows(), total=len(df), desc="Inserting packages"):
        if not_exist_in_package(conn, row['product_id'], distributor_id):
            
            distributor_code = row.get("product_details_code_saq")
            #print(f"Distributor code: {distributor_code}")
            pformat='BT'
            package_id = str(uuid4())
            packaging = row.get("product_details_format")
            product_id = row["product_id"]
            if product_id is None:
                print(f"Product ID is None for {row.get('product_name')}, skipping.")
                continue
            # print(f"Product ID: {product_id}")

            SQL = """
                INSERT INTO package (package_id, distributor_id, packaging, distributor_code, format, product_id)
                VALUES (%s, %s, %s, %s, %s, %s)
                ON CONFLICT (package_id) DO NOTHING
            """
            try:
                cursor.execute(SQL, (package_id, distributor_id, packaging, distributor_code, pformat, product_id))
                conn.commit()
            except Exception as e:
                conn.rollback()
                print(f"Error inserting package for {row.get('product_name')}: {e}")


    cursor.close()

# %%
print(dfwines[dfwines['product_id']== None])

# %%
conn = psycopg2.connect(DB_URL)
try: 
    insert_package(conn, dfwines, "SAQ")
except Exception as e:
    print(f"Error inserting package: {e}")
    conn.close()
finally:
    conn.close()
    print("Connection closed")

# %%
conn = psycopg2.connect(DB_URL)
insert_package(conn, dfwines, 'SAQ')
conn.close()

# %%
dfwines[dfwines['product_name']=='Domaine Porto Carras Malagouzia 2021']

# %%
df = load_data2(batch_start = 1501, batch_end=1908)
df = df[df['product_name'].notna() & (df['product_name'].str.strip() != '')]

dfwines = df[df['breadcrumb'].str.startswith("Produits > Vin", na=False)].copy()


conn = psycopg2.connect(DB_URL)

try: 
    update_subcategories(conn, dfwines)
except Exception as e:
    print(f"Error: {e}")
finally:
    conn.close()

conn = psycopg2.connect(DB_URL)
try: 
    upsert_wines(dfwines, conn)
except Exception as e:
    print(f"Error: {e}")
finally:
    conn.close()


conn = psycopg2.connect(DB_URL)
try: 
    update_product_volumes(dfwines, conn)
except Exception as e:
    print(f"Error: {e}")
finally:
    conn.close()

conn = psycopg2.connect(DB_URL)
try: 
    insert_package(conn, dfwines, "SAQ")
except Exception as e:
    print(f"Error inserting package: {e}")
    conn.close()
finally:
    conn.close()
    print("Connection closed")
